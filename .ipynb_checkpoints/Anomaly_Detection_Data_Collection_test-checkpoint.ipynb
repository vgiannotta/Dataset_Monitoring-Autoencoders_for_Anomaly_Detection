# %% [markdown]
# # Anomaly Detection: Using Deep Learning Methods to Monitor the Health of Automated Datasets
#
# I created this proposal and proof of concept for a hackweek project at Tyler Technologies in early 2023. The datasets discussed here are data assets that are housed in Tyler customer SaaS platforms as tabular datasets. In the use case described below, datasets are hosted and published in a given customer environment, and have accompanying ETL implemented such that data from their system of record – a separate database hosted elsewhere – is pulled on a given cadence through a scheduled process. The scheduled process is itself another Tyler product, which connects source systems to the Tyler environment, so that data can be visualized and shared.
#
#
# ### Problem
#
# Can we build infrastructure/services that monitor the health of a scheduled dataset?
#
# ### Use Case
#
# Our customers often automate datasets that are connected to their own source databases. These datasets are updated automatically, based on some specified cadence. Update failures, when they happen, are typically due to schema mismatches -- when the update data doesn't match the existing dataset in schema -- or connectivity issues to the source system. These errors are caught and made obvious by our established error handling infrastructure.
#
# There are however cases where an update can be faulty in terms of the *content* being published -- fewer rows than expected, erroneous values in a column, etc. -- and there is currently no tracking or error handling available to monitor for these types of issues. In other words, an update can run successfully, and the dataset can publish as expected, but the content of the data is inaccurate. Downstream metrics, vizzes, and reports will be inaccurate as well.
#
# Today, in order to validate the content of dataset updates, customers have to query their datasets themselves, and then proceed to compare the data to a previous update, or to data from the source system (or some other, likely manual, QA process).
#
# This method of issue remediation is costly. Customers must be proactive in monitoring their updates by establishing their own manual, labor-intensive QA process. Internally, Data Integrations spends more time troubleshooting data issues; because these "silent failures" often originate from the customer source system, DI engineers must investigate database architecture remotely, with little to no knowledge of or access to the database itself.
#
# Can we instead provide an opt-in service that automatically checks a dataset each time an update is published in the platform? The service would assess the dataset for completeness, obvious anomalies, or other inconsistencies that we prioritize. If health checks don't pass, the customer can be alerted by the service that their dataset may not have updated properly and take action.
#
# ### Building a Proof of Concept: Tasks for the Build
#
# The testing process and development process for a net-new monitoring service are linked, in that we will need to build an MVP of the service before we can fully understand the requirements to build in production. The approach laid out here is expected to be iterative and change along the way, but at a high level, the testing and development process can be broken out into phases:
#
# 1.  **Collect test data**
#     1.  In order to understand whether we *can* implement automated dataset monitoring, we need to know which specific events to monitor for, and how to obtain comprehensive data on these events.
#         1.  Tasks:
#             1.  Identify monitoring criteria.
#             2.  Collect a sample of the data. The sample should represent the dataset in its healthy state, as well as in an error state. If possible, the proportion of healthy observations to erroneous ones in the sample should be as realistic as possible. If the anomaly event is rare, there should only be a small number of errors in the sample, and a large number of "valid" records.
#
# 2.  **Create test environment**
#     1.  What IT resources are needed for testing? Can this be done with a demo domain and a local dev environment?
#         1.  Tasks:
#             1.  Identify and set up testing framework
#
# 3.  **Create archive dataset** (first time only)
#     1.  In order to monitor a dataset, we need to begin capturing metadata on the dataset each time an update happens. Dataset metadata will be captured in an archive dataset which lives on the same domain as the dataset to be monitored.
#         1.  Tasks:
#             1.  Define the metadata that should be captured on the dataset.
#             2.  Create a script that generates an archive dataset for the dataset being monitored, where each column is a specific piece of metadata.
#
# 4.  **Capture updates**
#     1.  Each time the monitored dataset undergoes an update, the archive repository dataset should capture metadata on the updates.
#         1.  Tasks:
#             1.  Create a script that runs whenever an update is made to the monitored dataset. The script should capture any of the defined pieces of metadata and append them to the archive repository dataset.
#
# 5.  **Analyze updates**
#     1.  With each update of the monitored dataset, analyze the archive data and determine the health of the dataset.
#         1.  Tasks:
#             1.  Set up model competition and analyze performance
#                 1.  PCA
#                 2.  Some kind of random forest?
#                 3.  Some kind of neural network?
#                 4.  Naive methods?
#             2.  Write script to assess the latest dataset update for health, using the best modeling method/s from the model competition. The archive history records are used as training data, and the most recent archive record is the test.
#             3.  Write the data from model assessment to a dataset? Maybe back to the archive dataset?
#                 1.  Could be interesting to create a viz from the results
#
# 6.  **If anomaly is detected, notify dataset owners**
#
#     1.  The notification method is dependent on customer needs, and also on the implementation path; do we need input from the customer in order to start this service on their domain, or can we just "turn on" the service?
#         1.  It should be said that this is a service meant to empower the dataset owners. The expectation is that customers will use this tool to monitor their own datasets. We internally take on the responsibility of monitoring the monitoring service, but we do not monitor datasets for the customer.
#         2.  Considering this, I strongly recommend that we have a requirements-gathering exchange with the customer as a pre-req for turning on the service. This would be a stop-gap to ensure that there is an agreement of customer ownership, giving us the ability to designate a real person who will receive and be custodian of any notifications.
#
# 7.  **Operationalize**
#     1.  Scripts can run in Airflow, with the DAG cadence set to one of the following:
#         1.  A brief time after the dataset is regularly scheduled to update
#             1.  pros:
#                 1.  The job only runs as often as necessary
#             2.  cons:
#                 1.  If a dataset takes too long to finish updating, the DAG could kick off before the update is complete, thereby missing the newest data
#                 2.  Manual data pulls would not be caught until the next scheduled runtime
#         2.  Very frequently
#             1.  pros:
#                 1.  We catch way more of the updates faster
#                 2.  If any of the scripts takes a long time / heavy resources to execute, the DAG could fail more often

# %% [markdown]
# ### Collecting Test Data for Anomaly Detection Monitoring
#
# _Project docs (Confluence): [Anomaly Detection Modeling](https://socrata.atlassian.net/wiki/spaces/~5d02b4deaf3a8f0c58e401e8/pages/2450227276/Anomaly+Detection+Modeling)_
#
# **Objective:** Collect a sample of the data. The sample should represent the dataset in its healthy state, as well as in an error state. If possible, the proportion of healthy observations to erroneous ones in the sample should be as realistic as possible. If the anomaly event is rare, there should only be a small number of errors in the sample, and a large number of “valid” records.
#
# **Test Case:** Filings (3 Years w/ rollups)
#
# **Socrata dataset:** https://internal-aoic.data.socrata.com/dataset/Filings-3-Years-w-rollups-/rt4a-u7gh
#
# **Data Source:** At this stage, we aim to collect metadata on the number of rows added, updated, and deleted with each update. The data dictionary below describes the schema of the data we'll use for modeling:
#
# | Column       | Description |
# | :----------  | :---------- |
# | timestamp    | String   |
# | rows_deleted | String   |
# | rows_updated | String   |
# | rows_created | String   |
#
# These metadata are not tracked by Socrata APIs, but we can pull this info from the Sumo logs. _Further down the road, we should see whether this info can be captured directly, assuming we have our plugins write out these details to the agent logs._ At the end of this notebook is a sample of info we could collect from the revisions endpoint, if need be.

# %%
import os
import re
import requests
import pandas as pd
import json
from Sumo_util import Sumo # <- this utility is just a local copy of dia-integrations-server/Utils/Sumo.py

domain = 'https://internal-aoic.data.socrata.com'
dataset = 'rt4a-u7gh'
username = os.environ['MY_SOCRATA_USERNAME']
password = os.environ['MY_SOCRATA_PASSWORD']

# %%
sumo = Sumo()

# Since the dataset was created on June 27, 2022, we need to pull all the updates for the lifetime of the dataset
response = sumo.search(
                        query="rows update summary AND rt4a-u7gh",
                        fromDate="2022-06-26T00:00:00", 
                        toDate="2023-01-11T00:00:00",
                        timezone="GMT")
# Out:
# Request Sumo search: {'query': 'rows update summary AND rt4a-u7gh', 'from': '2022-12-25T00:00:00', 'to': '2022-12-31T00:00:00', 'timeZone': 'GMT'}
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Request status: GATHERING RESULTS...
# Found 6 messages...

# %%
df
# Out:
#              timestamp rows_deleted rows_updated rows_created
# 0  2022-12-30 09:00:54            0         9122        24847
# 1  2022-12-29 09:02:49            0         9721        24611
# 2  2022-12-28 09:02:37            0        17968        21595
# 3  2022-12-27 09:04:30            0         1156         2361
# 4  2022-12-26 09:03:02            0            4          705
# 5  2022-12-25 09:00:21           55          295          489

# %%
[print(x) for x in response]
# Out:
# 2022-12-30 09:00:54,044 INFO  [mq2tl677un0aoa38ekg0tpaqh1hobapq] [59931 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=0, Rows Updated=9122, Rows Created=24847}
# 2022-12-29 09:02:49,228 INFO  [74ngis0f7b4ojebbtefa78thqq0n54ts] [52177 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=0, Rows Updated=9721, Rows Created=24611}
# 2022-12-28 09:02:37,914 INFO  [ncfsmtna580le89s1sqoso2qbnl52n9v] [46199 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=0, Rows Updated=17968, Rows Created=21595}
# 2022-12-27 09:04:30,798 INFO  [0cmr8mn4l50kbq6a6kq9qb00iidfrtd9] [36270 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=0, Rows Updated=1156, Rows Created=2361}
# 2022-12-26 09:03:02,898 INFO  [hsnrqinfpsrbaq8fd5eh0h19tv5hft36] [31465 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=0, Rows Updated=4, Rows Created=705}
# 2022-12-25 09:00:21,680 INFO  [jitem9lfrnlmnatflcggolqn02ujn65v] [24251 / internal-aoic.data.socrata.com id/rt4a-u7gh.json] resources.RowsService - rows update summary DatasetWriter nbe rt4a-u7gh {Rows Deleted=55, Rows Updated=295, Rows Created=489}
# [None, None, None, None, None, None]

# %%
# re.search('{(.*)}', response[0])[1].split(', ')[0].split('=')[1]

# %%
# result = re.search('{(.*)}', response[0])


# row_data = re.search('{(.*)}', response[0])[1]
# for x in row_data.split(', '):
#     df[x.split('=')[0]] = []
    
    
# for x in result[1].split(', '):
#     df[x.split('=')[0]] = re.search('\=(.*)', x)[1]

# %%
# Create header for df
df_dict = {'timestamp':[], 'rows_deleted': [], 'rows_updated': [], 'rows_created': []}

# Parse responses for update metadata
for x in response:
    df_dict['timestamp'].append(x[:19])
    df_dict['rows_deleted'].append(re.search('{(.*)}', x)[1].split(', ')[0].split('=')[1])
    df_dict['rows_updated'].append(re.search('{(.*)}', x)[1].split(', ')[1].split('=')[1])
    df_dict['rows_created'].append(re.search('{(.*)}', x)[1].split(', ')[2].split('=')[1])
    
df = pd.DataFrame(df_dict)
    
#     for y in re.search('{(.*)}', x)[1].split(', '):
#         key = y.split('=')[0]
#         value = y.split('=')[1]
#         df[key].extend(value)
    
#     df[x.split('=')[0]] = None
#     for y in result[1].split(', '):
#         re.search('\=(.*)', y)[1]

# %%
df.keys() = ['updated', 'deleted']
# Out:
#   Input In [94]
#     df.keys() = ['updated', 'deleted']
#     ^
# SyntaxError: cannot assign to function call

# %%
timestamp = []

[timestamp.append(x[:19]) for x in response]

# %% [markdown]
# What metadata can we get from the `revisions` endpoint?

# %%
dataset_id = 'rt4a-u7gh'

response = requests.get(f'{domain}/api/publishing/v1/revision/{dataset_id}', 
                        auth=(username,password), 
                        stream=True)
revisions = response.json()

# %%
f'{domain}/api/publishing/v1/revision/{dataset_id}'
# Out:
# 'https://internal-aoic.data.socrata.com/api/publishing/v1/revision/rt4a-u7gh'

# %%
revisions[0].keys()
# Out:
# dict_keys(['resource', 'links'])

# %%
rev_1_resource = revisions[0]['resource']
rev_2_resource = revisions[1]['resource']
rev_3_resource = revisions[2]['resource']
rev_4_resource = revisions[3]['resource']
rev_5_resource = revisions[4]['resource']

# %%
revisions[19]
# Out:
# {'resource': {'updated_at': '2022-12-19T06:02:15.968664Z',
#   'task_sets': [{'updated_at': '2022-12-19T06:02:13.730281Z',
#     'status': 'successful',
#     'request_id': '1l01l06pgjjgjilhe0ud30c1ip5o8iba',
#     'output_schema_id': 63891532,
#     'log': [{'time': '2022-12-19T06:01:45',
#       'stage': 'upsert_task',
#       'details': {'truth_data_version': 530,
#        'total_rows': 1563,
#        'error_count': 0,
#        'Rows Updated': 644,
#        'Rows Deleted': 0,
#        'Rows Created': 918,
#        'Errors': 1}},
#      {'time': '2022-12-19T06:01:34',
#       'stage': 'apply_metadata',
#       'details': {'diff': {'old': {'sorts': [],
#          'name': 'e-File AOIC Prod Filings',
#          'metadata': {'rowIdentifier': 554463289,
#           'availableDisplayTypes': ['table', 'fatrow', 'page']},
#          'displayType': 'table',
#          'attachments': []},
#         'new': {'sorts': [],
#          'privateMetadata': {'custom_fields': {}, 'contactEmail': None},
#          'name': 'e-File AOIC Prod Filings',
#          'metadata': {'rowIdentifier': 554463289,
#           'availableDisplayTypes': ['table', 'fatrow', 'page']},
#          'displayType': 'table',
#          'columns': [{'tableColumnId': 139408245,
#            'renderTypeName': 'number',
#            'position': 1,
#            'name': 'RowKey',
#            'id': 552437347,
#            'format': {},
#            'fieldName': 'rowkey',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '207433', 'count': '1'},
#              {'item': '410489', 'count': '1'},
#              {'item': '683251', 'count': '1'},
#              {'item': '2553566', 'count': '1'},
#              {'item': '2625181', 'count': '1'},
#              {'item': '2693764', 'count': '1'},
#              {'item': '2757192', 'count': '1'},
#              {'item': '3358189', 'count': '1'},
#              {'item': '4529425', 'count': '1'},
#              {'item': '4529437', 'count': '1'},
#              {'item': '4529454', 'count': '1'},
#              {'item': '4813603', 'count': '1'},
#              {'item': '4813650', 'count': '1'},
#              {'item': '4813690', 'count': '1'},
#              {'item': '4813782', 'count': '1'},
#              {'item': '5626865', 'count': '1'},
#              {'item': '5626888', 'count': '1'},
#              {'item': '7066596', 'count': '1'},
#              {'item': '7066654', 'count': '1'},
#              {'item': '7066712', 'count': '1'}],
#             'smallest': '4474',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '25718299',
#             'count': '6618943',
#             'cardinality': '6618943'}},
#           {'tableColumnId': 139408241,
#            'renderTypeName': 'text',
#            'position': 2,
#            'name': 'EFSPName',
#            'id': 552437348,
#            'format': {'align': 'left'},
#            'fieldName': 'efspname',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Odyssey File & Serve H5',
#               'count': '5106809'},
#              {'item': 'PohlmanUSA', 'count': '500002'},
#              {'item': 'OFS EFSP Filing Interface', 'count': '205290'},
#              {'item': 'i2File', 'count': '140706'},
#              {'item': 'Odyssey File & Serve Silverlight', 'count': '122861'},
#              {'item': 'GreenFiling', 'count': '122399'},
#              {'item': 'File & Serve Illinois', 'count': '107719'},
#              {'item': 'InfoTrack', 'count': '88007'},
#              {'item': 'ABC Legal', 'count': '62521'},
#              {'item': 'FireFly', 'count': '58831'},
#              {'item': 'a360', 'count': '30189'},
#              {'item': 'Court Filing', 'count': '20318'},
#              {'item': 'FileTime', 'count': '14853'},
#              {'item': 'Guide & File', 'count': '10660'},
#              {'item': 'OFS EFSP Kiosk', 'count': '7907'},
#              {'item': '1 eFile', 'count': '4768'},
#              {'item': 'Legal Document Management', 'count': '4502'},
#              {'item': 'Legal eFile', 'count': '3084'},
#              {'item': 'US Legal Pro', 'count': '3072'},
#              {'item': 'OneLegal', 'count': '2537'}],
#             'smallest': '1 eFile',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'US Legal Pro',
#             'count': '6618943',
#             'cardinality': '28'}},
#           {'tableColumnId': 139408256,
#            'renderTypeName': 'text',
#            'position': 3,
#            'name': 'County',
#            'id': 552437349,
#            'format': {},
#            'fieldName': 'county',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Cook', 'count': '2394970'},
#              {'item': 'Madison', 'count': '407854'},
#              {'item': 'Will', 'count': '381169'},
#              {'item': 'St. Clair', 'count': '346583'},
#              {'item': 'Dupage', 'count': '320339'},
#              {'item': 'Kane', 'count': '309238'},
#              {'item': 'Lake', 'count': '271204'},
#              {'item': 'Mclean', 'count': '161067'},
#              {'item': 'Winnebago', 'count': '157845'},
#              {'item': 'Sangamon', 'count': '123801'},
#              {'item': 'McHenry', 'count': '106586'},
#              {'item': 'Peoria', 'count': '99214'},
#              {'item': 'Rock Island', 'count': '75777'},
#              {'item': 'Champaign', 'count': '65774'},
#              {'item': 'Lasalle', 'count': '62478'},
#              {'item': 'Macon', 'count': '58344'},
#              {'item': 'Vermilion', 'count': '57238'},
#              {'item': 'Tazewell', 'count': '51843'},
#              {'item': 'Kendall', 'count': '50240'},
#              {'item': 'Kankakee', 'count': '49324'}],
#             'smallest': '1st District Appellate Court',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'zzTOGA TEST ONLY',
#             'count': '6618943',
#             'cardinality': '113'}},
#           {'tableColumnId': 139408247,
#            'renderTypeName': 'text',
#            'position': 4,
#            'name': 'Office',
#            'id': 552437350,
#            'format': {},
#            'fieldName': 'office',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'District Clerk',
#               'count': '2460644'},
#              {'item': 'Madison County', 'count': '407854'},
#              {'item': 'Will County', 'count': '381169'},
#              {'item': 'St. Clair County', 'count': '346583'},
#              {'item': 'DuPage County', 'count': '320339'},
#              {'item': 'Kane County', 'count': '309238'},
#              {'item': 'Lake County', 'count': '271204'},
#              {'item': 'McLean County', 'count': '161067'},
#              {'item': 'Winnebago County', 'count': '157845'},
#              {'item': 'Sangamon County', 'count': '123801'},
#              {'item': 'McHenry County', 'count': '106586'},
#              {'item': 'Peoria County', 'count': '99214'},
#              {'item': 'Rock Island County', 'count': '75777'},
#              {'item': 'Champaign County', 'count': '65774'},
#              {'item': 'LaSalle County', 'count': '62478'},
#              {'item': 'Macon County', 'count': '58344'},
#              {'item': 'Vermilion County', 'count': '57238'},
#              {'item': 'Tazewell County', 'count': '51843'},
#              {'item': 'Kendall County', 'count': '50240'},
#              {'item': 'Kankakee County', 'count': '49324'}],
#             'smallest': 'Adams County',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'zzTOGA TEST ONLY',
#             'count': '6618943',
#             'cardinality': '114'}},
#           {'tableColumnId': 139408239,
#            'renderTypeName': 'text',
#            'position': 5,
#            'name': 'OrgChartName',
#            'id': 552437351,
#            'format': {},
#            'fieldName': 'orgchartname',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Cook County - Municipal Civil - District 1 - Chicago',
#               'count': '568330'},
#              {'item': 'Cook County - Law - District 1 - Chicago',
#               'count': '549710'},
#              {'item': 'Madison County', 'count': '407854'},
#              {'item': 'Will County', 'count': '381169'},
#              {'item': 'St. Clair County', 'count': '346583'},
#              {'item': 'DuPage County', 'count': '320339'},
#              {'item': 'Kane County', 'count': '309238'},
#              {'item': 'Cook County - Domestic Relations - District 1 - Chicago',
#               'count': '293166'},
#              {'item': 'Cook County - Chancery - District 1 - Chicago',
#               'count': '271851'},
#              {'item': 'Lake County', 'count': '271204'},
#              {'item': 'Cook County - Probate  - District 1 - Chicago',
#               'count': '161872'},
#              {'item': 'McLean County', 'count': '161067'},
#              {'item': 'Winnebago County', 'count': '157845'},
#              {'item': 'Sangamon County', 'count': '123801'},
#              {'item': 'Cook County - County Division - District 1 - Chicago',
#               'count': '115099'},
#              {'item': 'McHenry County', 'count': '106586'},
#              {'item': 'Peoria County', 'count': '99214'},
#              {'item': 'Cook County - Municipal Civil - District 6 - Markham',
#               'count': '94557'},
#              {'item': 'Rock Island County', 'count': '75777'},
#              {'item': 'Cook County - Municipal Civil - District 5 - Bridgeview',
#               'count': '70812'}],
#             'smallest': '1st District Appellate Court',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'zzTOGA TEST ONLY',
#             'count': '6618943',
#             'cardinality': '175'}},
#           {'tableColumnId': 139408253,
#            'renderTypeName': 'number',
#            'position': 6,
#            'name': 'NodeID',
#            'id': 552437352,
#            'format': {},
#            'fieldName': 'nodeid',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '7551', 'count': '568330'},
#              {'item': '7851', 'count': '549710'},
#              {'item': '28000', 'count': '407854'},
#              {'item': '49000', 'count': '381169'},
#              {'item': '43000', 'count': '346583'},
#              {'item': '10500', 'count': '320339'},
#              {'item': '22000', 'count': '309238'},
#              {'item': '7751', 'count': '293166'},
#              {'item': '7511', 'count': '271851'},
#              {'item': '24000', 'count': '271204'},
#              {'item': '7901', 'count': '161872'},
#              {'item': '31500', 'count': '161067'},
#              {'item': '50000', 'count': '157845'},
#              {'item': '41000', 'count': '123801'},
#              {'item': '7610', 'count': '115099'},
#              {'item': '31000', 'count': '106586'},
#              {'item': '35500', 'count': '99214'},
#              {'item': '7556', 'count': '94557'},
#              {'item': '40000', 'count': '75777'},
#              {'item': '7555', 'count': '70812'}],
#             'smallest': '100',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '999999',
#             'count': '6618943',
#             'cardinality': '175'}},
#           {'tableColumnId': 139408263,
#            'renderTypeName': 'text',
#            'position': 7,
#            'name': 'CaseNumber',
#            'id': 552437353,
#            'format': {},
#            'fieldName': 'casenumber',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': '2018TX1', 'count': '6095'},
#              {'item': '2018TX000239', 'count': '2274'},
#              {'item': '2018TX000001', 'count': '2122'},
#              {'item': '2019TX1', 'count': '1781'},
#              {'item': '2018l008881', 'count': '1662'},
#              {'item': '2021CH1', 'count': '1633'},
#              {'item': '18TX201', 'count': '1543'},
#              {'item': '2021CH2', 'count': '1498'},
#              {'item': '2021L2', 'count': '1261'},
#              {'item': '2018TX4', 'count': '1256'},
#              {'item': '2021CH5', 'count': '1244'},
#              {'item': '2021CH4', 'count': '1224'},
#              {'item': '2021CH3', 'count': '1216'},
#              {'item': '2021L3', 'count': '1208'},
#              {'item': '2021L1', 'count': '1199'},
#              {'item': '2021P2', 'count': '1078'},
#              {'item': '2021P3', 'count': '991'},
#              {'item': '2021P6', 'count': '985'},
#              {'item': '2021P16', 'count': '981'},
#              {'item': '2021P12', 'count': '978'}],
#             'smallest': '0',
#             'null': '70961',
#             'non_null': '6547982',
#             'largest': 'TMP0092678',
#             'count': '6618943',
#             'cardinality': '678797'}},
#           {'tableColumnId': 139408252,
#            'renderTypeName': 'number',
#            'position': 8,
#            'name': 'EnvelopeID',
#            'id': 552437354,
#            'format': {},
#            'fieldName': 'envelopeid',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '12382698', 'count': '213'},
#              {'item': '12433162', 'count': '172'},
#              {'item': '12816862', 'count': '129'},
#              {'item': '12812776', 'count': '120'},
#              {'item': '12813572', 'count': '110'},
#              {'item': '13984450', 'count': '108'},
#              {'item': '12817810', 'count': '108'},
#              {'item': '15549821', 'count': '103'},
#              {'item': '11375391', 'count': '103'},
#              {'item': '13066969', 'count': '101'},
#              {'item': '14225727', 'count': '99'},
#              {'item': '13963749', 'count': '98'},
#              {'item': '13961318', 'count': '97'},
#              {'item': '13630698', 'count': '96'},
#              {'item': '13080007', 'count': '94'},
#              {'item': '13780642', 'count': '93'},
#              {'item': '12813857', 'count': '91'},
#              {'item': '12644112', 'count': '91'},
#              {'item': '12644759', 'count': '90'},
#              {'item': '15447555', 'count': '89'}],
#             'smallest': '4204',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '15919098',
#             'count': '6618943',
#             'cardinality': '3955477'}},
#           {'tableColumnId': 139408246,
#            'renderTypeName': 'text',
#            'position': 9,
#            'name': 'IsInitial',
#            'id': 552437355,
#            'format': {},
#            'fieldName': 'isinitial',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': '0', 'count': '5540673'},
#              {'item': '1', 'count': '1078270'}],
#             'smallest': '0',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '1',
#             'count': '6618943',
#             'cardinality': '2'}},
#           {'tableColumnId': 139408268,
#            'renderTypeName': 'number',
#            'position': 10,
#            'name': 'FilingID',
#            'id': 552437356,
#            'format': {},
#            'fieldName': 'filingid',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '207433', 'count': '1'},
#              {'item': '410489', 'count': '1'},
#              {'item': '683251', 'count': '1'},
#              {'item': '2553566', 'count': '1'},
#              {'item': '2625181', 'count': '1'},
#              {'item': '2693764', 'count': '1'},
#              {'item': '2757192', 'count': '1'},
#              {'item': '3358189', 'count': '1'},
#              {'item': '4529425', 'count': '1'},
#              {'item': '4529437', 'count': '1'},
#              {'item': '4529454', 'count': '1'},
#              {'item': '4813603', 'count': '1'},
#              {'item': '4813650', 'count': '1'},
#              {'item': '4813690', 'count': '1'},
#              {'item': '4813782', 'count': '1'},
#              {'item': '5626865', 'count': '1'},
#              {'item': '5626888', 'count': '1'},
#              {'item': '7066596', 'count': '1'},
#              {'item': '7066654', 'count': '1'},
#              {'item': '7066712', 'count': '1'}],
#             'smallest': '4474',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '25718299',
#             'count': '6618943',
#             'cardinality': '6618943'}},
#           {'tableColumnId': 139408262,
#            'renderTypeName': 'text',
#            'position': 11,
#            'name': 'FilingType',
#            'id': 552437357,
#            'format': {},
#            'fieldName': 'filingtype',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'EFile', 'count': '4838131'},
#              {'item': 'EFileAndServe', 'count': '1780812'}],
#             'smallest': 'EFile',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'EFileAndServe',
#             'count': '6618943',
#             'cardinality': '2'}},
#           {'tableColumnId': 139408264,
#            'renderTypeName': 'calendar_date',
#            'position': 12,
#            'name': 'Submitted',
#            'id': 552437358,
#            'format': {},
#            'fieldName': 'submitted',
#            'description': '',
#            'dataTypeName': 'calendar_date',
#            'cachedContents': {'top': [{'item': '2021-03-03T10:44:49.473',
#               'count': '213'},
#              {'item': '2021-03-04T14:44:06.700', 'count': '172'},
#              {'item': '2021-04-02T14:03:58.970', 'count': '129'},
#              {'item': '2021-04-02T10:31:57.300', 'count': '120'},
#              {'item': '2021-04-02T11:07:55.377', 'count': '112'},
#              {'item': '2021-07-09T15:31:57.897', 'count': '108'},
#              {'item': '2021-04-02T15:02:35.817', 'count': '108'},
#              {'item': '2021-11-10T11:41:57.060', 'count': '103'},
#              {'item': '2020-12-04T17:16:15.697', 'count': '103'},
#              {'item': '2021-04-23T09:13:38.787', 'count': '101'},
#              {'item': '2021-07-28T15:43:16.493', 'count': '99'},
#              {'item': '2021-07-08T12:11:34.107', 'count': '98'},
#              {'item': '2021-07-08T10:33:45.533', 'count': '97'},
#              {'item': '2021-06-09T15:27:01.267', 'count': '96'},
#              {'item': '2021-04-25T08:24:05.573', 'count': '94'},
#              {'item': '2021-06-22T14:25:49.130', 'count': '93'},
#              {'item': '2021-04-02T11:18:28.897', 'count': '91'},
#              {'item': '2021-03-19T12:15:16.040', 'count': '91'},
#              {'item': '2021-11-02T15:56:17.610', 'count': '90'},
#              {'item': '2021-03-19T12:43:11.203', 'count': '90'}],
#             'smallest': '2017-02-09T19:08:04.260',
#             'null': '2656',
#             'non_null': '6616287',
#             'largest': '2021-12-12T00:02:15.370',
#             'count': '6618943',
#             'cardinality': '3943566'}},
#           {'tableColumnId': 139408269,
#            'renderTypeName': 'text',
#            'position': 13,
#            'name': 'SubmittedDay',
#            'id': 552437359,
#            'format': {},
#            'fieldName': 'submittedday',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Tuesday', 'count': '1405466'},
#              {'item': 'Wednesday', 'count': '1403498'},
#              {'item': 'Thursday', 'count': '1278178'},
#              {'item': 'Monday', 'count': '1237256'},
#              {'item': 'Friday', 'count': '1188968'},
#              {'item': 'Sunday', 'count': '53738'},
#              {'item': 'Saturday', 'count': '49183'}],
#             'smallest': 'Friday',
#             'null': '2656',
#             'non_null': '6616287',
#             'largest': 'Wednesday',
#             'count': '6618943',
#             'cardinality': '7'}},
#           {'tableColumnId': 139408257,
#            'renderTypeName': 'text',
#            'position': 14,
#            'name': 'FilingState',
#            'id': 552437360,
#            'format': {},
#            'fieldName': 'filingstate',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'AcceptedByCourt',
#               'count': '6107085'},
#              {'item': 'RejectedByCourt', 'count': '447892'},
#              {'item': 'Receipted', 'count': '45458'},
#              {'item': 'Submitted', 'count': '14792'},
#              {'item': 'UnderReview', 'count': '2812'},
#              {'item': 'Reviewed', 'count': '904'}],
#             'smallest': 'AcceptedByCourt',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'UnderReview',
#             'count': '6618943',
#             'cardinality': '6'}},
#           {'tableColumnId': 139408244,
#            'renderTypeName': 'text',
#            'position': 15,
#            'name': 'CaseCategoryCode',
#            'id': 552437361,
#            'format': {},
#            'fieldName': 'casecategorycode',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Civil', 'count': '904963'},
#              {'item': 'Law: Damages over $50,000', 'count': '894937'},
#              {'item': 'Small Claims', 'count': '755390'},
#              {'item': 'Dissolution (Divorce)', 'count': '510065'},
#              {'item': 'Personal Injury/Wrongful Death', 'count': '439675'},
#              {'item': 'Probate', 'count': '345054'},
#              {'item': 'Family', 'count': '280675'},
#              {'item': 'Chancery', 'count': '232403'},
#              {'item': 'Criminal Felony', 'count': '213175'},
#              {'item': 'Domestic Relations - General Proceedings',
#               'count': '202020'},
#              {'item': 'Law Magistrate: Damages over $10,000 up to $50,000',
#               'count': '169861'},
#              {'item': 'Mortgage Foreclosure', 'count': '152513'},
#              {'item': 'Arbitration', 'count': '128012'},
#              {'item': 'Tax', 'count': '122659'},
#              {'item': 'Miscellaneous Remedy', 'count': '117832'},
#              {'item': 'General Chancery', 'count': '108999'},
#              {'item': 'Deceased', 'count': '101617'},
#              {'item': 'Juvenile Abuse', 'count': '94056'},
#              {'item': 'Commercial Litigation', 'count': '92398'},
#              {'item': 'General Proceedings', 'count': '77558'}],
#             'smallest': 'Administrative',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'Transfer Protective Order',
#             'count': '6618943',
#             'cardinality': '76'}},
#           {'tableColumnId': 139408255,
#            'renderTypeName': 'text',
#            'position': 16,
#            'name': 'CaseTypeCode',
#            'id': 552437362,
#            'format': {},
#            'fieldName': 'casetypecode',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Asbestos (Negligence) (over $50,000.00)',
#               'count': '514173'},
#              {'item': 'Breach of Contract', 'count': '426173'},
#              {'item': 'Contract ($2,500.01 to $10K)', 'count': '211145'},
#              {'item': 'Dissolution (with children)', 'count': '205972'},
#              {'item': 'Small Claims', 'count': '204788'},
#              {'item': 'Consumer Debt', 'count': '198040'},
#              {'item': 'Felony', 'count': '190180'},
#              {'item': 'Contract (Up to $2,500)', 'count': '187615'},
#              {'item': 'Petition For Dissolution', 'count': '185265'},
#              {'item': 'Tort - Money Damages (over $50,000.00)',
#               'count': '181401'},
#              {'item': 'Dissolution', 'count': '144840'},
#              {'item': 'Motor Vehicle - Jury Demand', 'count': '123077'},
#              {'item': 'Probate', 'count': '109923'},
#              {'item': 'Owner Occupied Single-Family Home/Condo',
#               'count': '107131'},
#              {'item': "Administration of Decedent's Estate",
#               'count': '107129'},
#              {'item': 'Juvenile Abuse', 'count': '88383'},
#              {'item': 'Dissolution (without children)', 'count': '81333'},
#              {'item': 'Other Personal Injury / Wrongful Death - Jury Demand',
#               'count': '73828'},
#              {'item': 'Family', 'count': '73213'},
#              {'item': 'Petition for Dissolution', 'count': '71049'}],
#             'smallest': 'Abandoned Baby',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'Wrongful Death (Up to $50K)',
#             'count': '6618943',
#             'cardinality': '1944'}},
#           {'tableColumnId': 139408237,
#            'renderTypeName': 'text',
#            'position': 17,
#            'name': 'FilingCode',
#            'id': 552437363,
#            'format': {},
#            'fieldName': 'filingcode',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Motion', 'count': '340910'},
#              {'item': 'Notice', 'count': '285115'},
#              {'item': 'Proposed Order', 'count': '272587'},
#              {'item': 'Affidavit', 'count': '235176'},
#              {'item': 'Exhibits Filed', 'count': '188692'},
#              {'item': 'Motion Filed', 'count': '178948'},
#              {'item': 'Notice of Motion Filed', 'count': '165228'},
#              {'item': 'Summons (Issued)', 'count': '155584'},
#              {'item': 'Notice of Filing Filed', 'count': '134580'},
#              {'item': 'Summons Issued And Returnable', 'count': '132173'},
#              {'item': 'Other Document Not Listed', 'count': '132019'},
#              {'item': 'Notice Filed', 'count': '129317'},
#              {'item': 'Order', 'count': '127849'},
#              {'item': 'Appearance', 'count': '126234'},
#              {'item': 'Complaint', 'count': '121957'},
#              {'item': 'Proof Of Service/Certificate of Service',
#               'count': '120336'},
#              {'item': 'Alias Summons - Issued and Returnable',
#               'count': '113301'},
#              {'item': 'Petition', 'count': '97561'},
#              {'item': 'Notice Of Hearing', 'count': '84358'},
#              {'item': 'Certificate', 'count': '79203'}],
#             'smallest': '2-50 Affidavit',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'z – Other Document Not Listed',
#             'count': '6618943',
#             'cardinality': '4985'}},
#           {'tableColumnId': 139408248,
#            'renderTypeName': 'text',
#            'position': 18,
#            'name': 'IsIndividualFirm',
#            'id': 552437364,
#            'format': {},
#            'fieldName': 'isindividualfirm',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Firm', 'count': '6091583'},
#              {'item': 'Individual', 'count': '527360'}],
#             'smallest': 'Firm',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'Individual',
#             'count': '6618943',
#             'cardinality': '2'}},
#           {'tableColumnId': 139408254,
#            'renderTypeName': 'text',
#            'position': 19,
#            'name': 'UserName',
#            'id': 552437365,
#            'format': {},
#            'fieldName': 'username',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'docketingteam@blittandgaines.com',
#               'count': '330715'},
#              {'item': 'nicholass@kohnlaw.com', 'count': '90356'},
#              {'item': 'brianc@barristersweb.net', 'count': '74943'},
#              {'item': 'CookEFiling@blittandgaines.com', 'count': '57686'},
#              {'item': 'MandarichIL@abclegal.com', 'count': '45909'},
#              {'item': 'jennifer.severus@il.cslegal.com', 'count': '45729'},
#              {'item': 'mattr@kohnlaw.com', 'count': '42871'},
#              {'item': 'Provana2@shindlerlaw.com', 'count': '39107'},
#              {'item': 'mworders@uslegalsupport.com', 'count': '35422'},
#              {'item': 'SouthernIL@blittandgaines.com', 'count': '34479'},
#              {'item': 'illinoislitigation@zwickerpc.com', 'count': '33737'},
#              {'item': 'rmoreno@weltman.com', 'count': '29542'},
#              {'item': 'CentralIL@blittandgaines.com', 'count': '28217'},
#              {'item': 'efileILreturns@firefly.pro', 'count': '26284'},
#              {'item': 'ccarr@lloydmc.com', 'count': '23132'},
#              {'item': 'IL.EFILINGS@provest.us', 'count': '20444'},
#              {'item': 'rberg@logs.com', 'count': '19733'},
#              {'item': 'kevin.egan@portfoliorecovery.com', 'count': '19254'},
#              {'item': 'HOME.LAW-DORN@STATEFARM.COM', 'count': '18776'},
#              {'item': 'ilfcefiling@mccalla.com', 'count': '18632'}],
#             'smallest': '000NLH@GMAIL.COM',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': 'zzweizig@yahoo.com',
#             'count': '6618943',
#             'cardinality': '92853'}},
#           {'tableColumnId': 139408251,
#            'renderTypeName': 'number',
#            'position': 20,
#            'name': 'FirmID',
#            'id': 552437366,
#            'format': {},
#            'fieldName': 'firmid',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '9246', 'count': '388401'},
#              {'item': '45856', 'count': '133227'},
#              {'item': '5827', 'count': '74943'},
#              {'item': '8468', 'count': '73128'},
#              {'item': '3295', 'count': '62696'},
#              {'item': '353', 'count': '57507'},
#              {'item': '2731', 'count': '50448'},
#              {'item': '36546', 'count': '45909'},
#              {'item': '480573', 'count': '44239'},
#              {'item': '387', 'count': '43248'},
#              {'item': '271', 'count': '43119'},
#              {'item': '92873', 'count': '42186'},
#              {'item': '2703', 'count': '40423'},
#              {'item': '2898', 'count': '39177'},
#              {'item': '24727', 'count': '35422'},
#              {'item': '274', 'count': '33737'},
#              {'item': '4207', 'count': '32848'},
#              {'item': '3326', 'count': '29883'},
#              {'item': '8410', 'count': '29606'},
#              {'item': '443', 'count': '29542'}],
#             'smallest': '-1',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '573824',
#             'count': '6618943',
#             'cardinality': '81084'}},
#           {'tableColumnId': 139408266,
#            'renderTypeName': 'text',
#            'position': 21,
#            'name': 'FirmName',
#            'id': 552437367,
#            'format': {},
#            'fieldName': 'firmname',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Individual',
#               'count': '606640'},
#              {'item': 'Blitt & Gaines, P.C.', 'count': '451097'},
#              {'item': 'Kohn Law Firm S.C.', 'count': '133227'},
#              {'item': 'Mandarich Law Group', 'count': '75792'},
#              {'item': 'The Gori Law Firm, P.C.', 'count': '73128'},
#              {'item': 'Codilis & Associates, P.C.', 'count': '57507'},
#              {'item': 'McLean County Circuit Court', 'count': '50448'},
#              {'item': 'Kane County Judicial Administrator', 'count': '44239'},
#              {'item': 'Midland Credit Management', 'count': '43248'},
#              {'item': 'Shindler & Joyce Law Firm', 'count': '43119'},
#              {'item': 'Markoff Law LLC', 'count': '40425'},
#              {'item': 'Swanson, Martin & Bell, LLP', 'count': '40117'},
#              {'item': 'Zwicker & Associates, P.C.', 'count': '33737'},
#              {'item': "Kane County State's Attorney's Office",
#               'count': '32973'},
#              {'item': 'Segal McCambridge Singer Mahoney, Ltd.',
#               'count': '29606'},
#              {'item': 'Weltman, Weinberg & Reis Co., L.P.A', 'count': '29542'},
#              {'item': 'Armstrong Teasdale', 'count': '29066'},
#              {'item': 'Resurgence Legal Group PC', 'count': '28358'},
#              {'item': 'Sinars Slowikowski Tomaska LLC', 'count': '26022'},
#              {'item': 'Rasmussen Dickey Moore LLC', 'count': '24804'}],
#             'smallest': '----',
#             'null': '27872',
#             'non_null': '6591071',
#             'largest': 'ZwillGen PLLC',
#             'count': '6618943',
#             'cardinality': '17602'}},
#           {'tableColumnId': 139408250,
#            'renderTypeName': 'text',
#            'position': 22,
#            'name': 'RejectionReason',
#            'id': 552437368,
#            'format': {},
#            'fieldName': 'rejectionreason',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Rejected', 'count': '380696'},
#              {'item': 'Missing Items', 'count': '10753'},
#              {'item': 'Multiple filings submitted as one transaction',
#               'count': '7198'},
#              {'item': 'Format Error', 'count': '6029'},
#              {'item': 'Incorrect Fees', 'count': '5672'},
#              {'item': 'Other', 'count': '4624'},
#              {'item': 'Incorrect Date', 'count': '3528'},
#              {'item': "Unable to schedule date. Please contact judge's secretary.",
#               'count': '1749'},
#              {'item': 'Single Filing submitted as multiple transactions',
#               'count': '1747'},
#              {'item': 'Incorrect Venue', 'count': '1686'},
#              {'item': 'Orders need to be submitted electronically through https://eaccess.18thjudicial.org',
#               'count': '1648'},
#              {'item': 'No appearance for this attorney filed on this case',
#               'count': '1574'},
#              {'item': 'Document cannot be filed in its current format.',
#               'count': '1417'},
#              {'item': 'Missing Filing Fee', 'count': '1393'},
#              {'item': 'Absent or Improper of Proof of Service',
#               'count': '1256'},
#              {'item': 'Court Date Error', 'count': '1177'},
#              {'item': 'Document not signed or properly signed',
#               'count': '1112'},
#              {'item': 'Missing appropriate fee under optional services',
#               'count': '1064'},
#              {'item': 'Document not text (PDF) searchable', 'count': '826'},
#              {'item': 'Transaction rejected', 'count': '722'}],
#             'smallest': 'Absence of Circuit Court Clerk File-mark',
#             'null': '6170034',
#             'non_null': '448909',
#             'largest': 'Wrong Filing Fees',
#             'count': '6618943',
#             'cardinality': '101'}},
#           {'tableColumnId': 140176379,
#            'renderTypeName': 'text',
#            'position': 23,
#            'name': 'FSHSubmitted',
#            'id': 552437384,
#            'format': {},
#            'fieldName': 'fshsubmitted',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'null': '6618943',
#             'non_null': '0',
#             'count': '6618943',
#             'cardinality': '0'}},
#           {'tableColumnId': 140176378,
#            'renderTypeName': 'text',
#            'position': 24,
#            'name': 'FSHUnderReview',
#            'id': 552437383,
#            'format': {},
#            'fieldName': 'fshunderreview',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'null': '6618943',
#             'non_null': '0',
#             'count': '6618943',
#             'cardinality': '0'}},
#           {'tableColumnId': 140176377,
#            'renderTypeName': 'text',
#            'position': 25,
#            'name': 'FSHReviewed',
#            'id': 552437382,
#            'format': {},
#            'fieldName': 'fshreviewed',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'null': '6618943',
#             'non_null': '0',
#             'count': '6618943',
#             'cardinality': '0'}},
#           {'tableColumnId': 139408236,
#            'renderTypeName': 'number',
#            'position': 26,
#            'name': 'NumberOfDocuments',
#            'id': 552437372,
#            'format': {},
#            'fieldName': 'numberofdocuments',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '1', 'count': '6561570'},
#              {'item': '2', 'count': '40029'},
#              {'item': '3', 'count': '6838'},
#              {'item': '6', 'count': '4102'},
#              {'item': '4', 'count': '2940'},
#              {'item': '5', 'count': '1456'},
#              {'item': '7', 'count': '547'},
#              {'item': '8', 'count': '333'},
#              {'item': '9', 'count': '206'},
#              {'item': '10', 'count': '174'},
#              {'item': '11', 'count': '121'},
#              {'item': '12', 'count': '110'},
#              {'item': '13', 'count': '78'},
#              {'item': '14', 'count': '51'},
#              {'item': '15', 'count': '47'},
#              {'item': '16', 'count': '31'},
#              {'item': '18', 'count': '29'},
#              {'item': '17', 'count': '28'},
#              {'item': '19', 'count': '22'},
#              {'item': '20', 'count': '22'}],
#             'smallest': '1',
#             'null': '119',
#             'non_null': '6618824',
#             'largest': '117',
#             'count': '6618943',
#             'cardinality': '42'}},
#           {'tableColumnId': 139408258,
#            'renderTypeName': 'calendar_date',
#            'position': 27,
#            'name': 'UnderReview',
#            'id': 552437373,
#            'format': {},
#            'fieldName': 'underreview',
#            'description': '',
#            'dataTypeName': 'calendar_date',
#            'cachedContents': {'top': [{'item': '2021-03-03T11:13:49.050',
#               'count': '213'},
#              {'item': '2021-03-04T14:44:21.003', 'count': '172'},
#              {'item': '2021-04-05T13:16:15.817', 'count': '129'},
#              {'item': '2021-04-05T10:27:54.777', 'count': '120'},
#              {'item': '2021-04-05T11:00:30.717', 'count': '110'},
#              {'item': '2021-04-05T13:28:32.697', 'count': '108'},
#              {'item': '2021-07-12T07:58:47.307', 'count': '108'},
#              {'item': '2020-12-07T12:05:24.180', 'count': '103'},
#              {'item': '2021-11-10T13:30:41.820', 'count': '103'},
#              {'item': '2021-04-23T11:28:35.493', 'count': '101'},
#              {'item': '2021-07-28T19:57:45.483', 'count': '99'},
#              {'item': '2021-07-09T08:59:22.927', 'count': '98'},
#              {'item': '2021-07-09T07:01:15.183', 'count': '97'},
#              {'item': '2021-06-10T15:52:34.803', 'count': '96'},
#              {'item': '2021-04-26T08:07:28.153', 'count': '94'},
#              {'item': '2021-06-22T15:14:20.580', 'count': '93'},
#              {'item': '2021-03-19T13:29:53.750', 'count': '91'},
#              {'item': '2021-04-05T11:29:49.880', 'count': '91'},
#              {'item': '2021-03-19T14:06:57.450', 'count': '90'},
#              {'item': '2021-11-30T10:49:10.587', 'count': '89'}],
#             'smallest': '2017-10-17T15:57:44.000',
#             'null': '14938',
#             'non_null': '6604005',
#             'largest': '2021-12-12T00:00:11.333',
#             'count': '6618943',
#             'cardinality': '3942067'}},
#           {'tableColumnId': 139408265,
#            'renderTypeName': 'calendar_date',
#            'position': 28,
#            'name': 'Reviewed',
#            'id': 552437374,
#            'format': {},
#            'fieldName': 'reviewed',
#            'description': '',
#            'dataTypeName': 'calendar_date',
#            'cachedContents': {'top': [{'item': '2021-03-04T15:21:35.020',
#               'count': '172'},
#              {'item': '2021-04-05T14:17:14.490', 'count': '129'},
#              {'item': '2021-04-05T10:58:15.360', 'count': '120'},
#              {'item': '2021-04-05T14:04:24.140', 'count': '108'},
#              {'item': '2021-07-12T08:09:40.580', 'count': '108'},
#              {'item': '2020-12-07T12:12:12.713', 'count': '103'},
#              {'item': '2021-11-10T14:15:19.903', 'count': '103'},
#              {'item': '2021-04-23T11:49:45.220', 'count': '101'},
#              {'item': '2021-07-28T20:13:27.747', 'count': '99'},
#              {'item': '2021-07-09T12:57:52.610', 'count': '98'},
#              {'item': '2021-07-09T07:35:24.843', 'count': '97'},
#              {'item': '2021-06-10T16:07:28.207', 'count': '96'},
#              {'item': '2021-04-26T08:46:59.133', 'count': '94'},
#              {'item': '2021-04-05T12:36:25.610', 'count': '93'},
#              {'item': '2021-06-22T15:30:54.633', 'count': '93'},
#              {'item': '2021-04-05T11:48:24.553', 'count': '91'},
#              {'item': '2021-03-19T15:09:31.717', 'count': '90'},
#              {'item': '2021-06-10T14:13:24.167', 'count': '89'},
#              {'item': '2021-11-03T12:48:04.073', 'count': '89'},
#              {'item': '2021-03-19T13:50:41.473', 'count': '89'}],
#             'smallest': '2017-10-17T16:01:24.290',
#             'null': '455507',
#             'non_null': '6163436',
#             'largest': '2021-12-12T00:01:33.227',
#             'count': '6618943',
#             'cardinality': '3720214'}},
#           {'tableColumnId': 139408240,
#            'renderTypeName': 'number',
#            'position': 29,
#            'name': 'PrimaryAmount',
#            'id': 552437375,
#            'format': {},
#            'fieldName': 'primaryamount',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '0.0000', 'count': '4777163'},
#              {'item': '189.0000', 'count': '193303'},
#              {'item': '379.0000', 'count': '147944'},
#              {'item': '388.0000', 'count': '107260'},
#              {'item': '6.0000', 'count': '103805'},
#              {'item': '287.0000', 'count': '87272'},
#              {'item': '30.0000', 'count': '54378'},
#              {'item': '251.0000', 'count': '49118'},
#              {'item': '5.0000', 'count': '47595'},
#              {'item': '314.0000', 'count': '44609'},
#              {'item': '89.0000', 'count': '39930'},
#              {'item': '463.5000', 'count': '37056'},
#              {'item': '50.0000', 'count': '36508'},
#              {'item': '45.0000', 'count': '28489'},
#              {'item': '293.0000', 'count': '26272'},
#              {'item': '364.0000', 'count': '24427'},
#              {'item': '284.0000', 'count': '23524'},
#              {'item': '75.0000', 'count': '23341'},
#              {'item': '334.0000', 'count': '23297'},
#              {'item': '256.0000', 'count': '22533'}],
#             'smallest': '0.0000',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '9408.0000',
#             'count': '6618943',
#             'cardinality': '2354'}},
#           {'tableColumnId': 139408238,
#            'renderTypeName': 'number',
#            'position': 30,
#            'name': 'SecondaryAmount',
#            'id': 552437376,
#            'format': {},
#            'fieldName': 'secondaryamount',
#            'description': '',
#            'dataTypeName': 'number',
#            'cachedContents': {'top': [{'item': '0.0000', 'count': '4688904'},
#              {'item': '0.2500', 'count': '530825'},
#              {'item': '10.9500', 'count': '119861'},
#              {'item': '0.1700', 'count': '82851'},
#              {'item': '1.0300', 'count': '71992'},
#              {'item': '11.2100', 'count': '69159'},
#              {'item': '8.2900', 'count': '63980'},
#              {'item': '3.0800', 'count': '58414'},
#              {'item': '3.0900', 'count': '40601'},
#              {'item': '7.2500', 'count': '35302'},
#              {'item': '0.8700', 'count': '34582'},
#              {'item': '0.1400', 'count': '32956'},
#              {'item': '1.2500', 'count': '26854'},
#              {'item': '3.2500', 'count': '26091'},
#              {'item': '9.0700', 'count': '25642'},
#              {'item': '13.4000', 'count': '25178'},
#              {'item': '2.5700', 'count': '24479'},
#              {'item': '1.4400', 'count': '24282'},
#              {'item': '1.3000', 'count': '20133'},
#              {'item': '8.2100', 'count': '18417'}],
#             'smallest': '-1.0000',
#             'null': '0',
#             'non_null': '6618943',
#             'largest': '271.8900',
#             'count': '6618943',
#             'cardinality': '1805'}},
#           {'tableColumnId': 139408249,
#            'renderTypeName': 'text',
#            'position': 31,
#            'name': 'SystemPaymentAccountType',
#            'id': 552437377,
#            'format': {},
#            'fieldName': 'systempaymentaccounttype',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'CreditCard',
#               'count': '3824787'},
#              {'item': 'BankAccount', 'count': '1658336'},
#              {'item': 'Waiver', 'count': '1057883'},
#              {'item': 'Cash', 'count': '7380'}],
#             'smallest': 'BankAccount',
#             'null': '70557',
#             'non_null': '6548386',
#             'largest': 'Waiver',
#             'count': '6618943',
#             'cardinality': '4'}},
#           {'tableColumnId': 139408242,
#            'renderTypeName': 'text',
#            'position': 32,
#            'name': 'Clerkname',
#            'id': 552437378,
#            'format': {},
#            'fieldName': 'clerkname',
#            'description': '',
#            'dataTypeName': 'text',
#            'cachedContents': {'top': [{'item': 'Edwards, Michele',
#               'count': '120683'},
#              {'item': 'Rose, Abbey', 'count': '112230'},
#              {'item': 'Shipbaugh, Coleen', 'count': '102519'},
#              {'item': 'LOFTON, SHANELL', 'count': '100584'},
#              {'item': 'Carney, Theresa', 'count': '98570'},
#              {'item': 'THOMAS, Michelle', 'count': '73761'},
#              {'item': 'Forbes, Sara', 'count': '72492'},
#              {'item': 'Sumrall, Vonda', 'count': '70920'},
#              {'item': 'Wilson, Diane', 'count': '62797'},
#              {'item': 'Battiato, Shannon', 'count': '62299'},
#              {'item': 'Griffin, Natasha D.', 'count': '58529'},
#              {'item': 'Lovell, John', 'count': '58141'},
#              {'item': 'Reyes, Debra', 'count': '53679'},
#              {'item': 'Delrose, Alexa', 'count': '52049'},
#              {'item': 'Joshi, Sonal', 'count': '49559'},
#              {'item': 'Mojica, Cecilia', 'count': '49102'},
#              {'item': 'Kennerly, Sara', 'count': '48059'},
#              {'item': 'System, System', 'count': '47667'},
#              {'item': 'Ledesma, D', 'count': '47401'},
#              {'item': 'Demos, Elena', 'count': '47284'}],
#             'smallest': '2 Admin, Cook District',
#             'null': '455507',
#             'non_null': '6163436',
#             'largest': 'Zurawska, Anna',
#             'count': '6618943',
#             'cardinality': '1510'}},
#           {'tableColumnId': 139408261,
#            'renderTypeName': 'calendar_date',
#            'position': 33,
#            'name': 'AdjustedSubmitDate',
#            'id': 552437379,
#            'format': {},
#            'fieldName': 'adjustedsubmitdate',
#            'description': '',
#            'dataTypeName': 'calendar_date',
#            'cachedContents': {'top': [{'item': '2021-11-15T07:00:00.000',
#               'count': '4529'},
#              {'item': '2021-02-22T07:00:00.000', 'count': '4352'},
#              {'item': '2021-02-01T07:00:00.000', 'count': '4338'},
#              {'item': '2020-12-21T07:00:00.000', 'count': '4039'},
#              {'item': '2021-01-11T07:00:00.000', 'count': '3995'},
#              {'item': '2020-12-07T07:00:00.000', 'count': '3935'},
#              {'item': '2021-03-01T07:00:00.000', 'count': '3932'},
#              {'item': '2021-02-08T07:00:00.000', 'count': '3847'},
#              {'item': '2021-11-22T07:00:00.000', 'count': '3768'},
#              {'item': '2021-01-18T07:00:00.000', 'count': '3695'},
#              {'item': '2021-12-13T07:00:00.000', 'count': '3573'},
#              {'item': '2021-06-28T07:00:00.000', 'count': '3513'},
# ...
#        {'item': 'Orders need to be submitted electronically through https://eaccess.18thjudicial.org',
#         'count': '1648'},
#        {'item': 'No appearance for this attorney filed on this case',
#         'count': '1574'},
#        {'item': 'Document cannot be filed in its current format.',
#         'count': '1417'},
#        {'item': 'Missing Filing Fee', 'count': '1393'},
#        {'item': 'Absent or Improper of Proof of Service', 'count': '1256'},
#        {'item': 'Court Date Error', 'count': '1177'},
#        {'item': 'Document not signed or properly signed', 'count': '1112'},
#        {'item': 'Missing appropriate fee under optional services',
#         'count': '1064'},
#        {'item': 'Document not text (PDF) searchable', 'count': '826'},
#        {'item': 'Transaction rejected', 'count': '722'}],
#       'smallest': 'Absence of Circuit Court Clerk File-mark',
#       'null': '6170034',
#       'non_null': '448909',
#       'largest': 'Wrong Filing Fees',
#       'count': '6618943',
#       'cardinality': '101'}},
#     {'tableColumnId': 140176379,
#      'renderTypeName': 'text',
#      'position': 23,
#      'name': 'FSHSubmitted',
#      'id': 552437384,
#      'format': {},
#      'fieldName': 'fshsubmitted',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'null': '6618943',
#       'non_null': '0',
#       'count': '6618943',
#       'cardinality': '0'}},
#     {'tableColumnId': 140176378,
#      'renderTypeName': 'text',
#      'position': 24,
#      'name': 'FSHUnderReview',
#      'id': 552437383,
#      'format': {},
#      'fieldName': 'fshunderreview',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'null': '6618943',
#       'non_null': '0',
#       'count': '6618943',
#       'cardinality': '0'}},
#     {'tableColumnId': 140176377,
#      'renderTypeName': 'text',
#      'position': 25,
#      'name': 'FSHReviewed',
#      'id': 552437382,
#      'format': {},
#      'fieldName': 'fshreviewed',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'null': '6618943',
#       'non_null': '0',
#       'count': '6618943',
#       'cardinality': '0'}},
#     {'tableColumnId': 139408236,
#      'renderTypeName': 'number',
#      'position': 26,
#      'name': 'NumberOfDocuments',
#      'id': 552437372,
#      'format': {},
#      'fieldName': 'numberofdocuments',
#      'description': '',
#      'dataTypeName': 'number',
#      'cachedContents': {'top': [{'item': '1', 'count': '6561570'},
#        {'item': '2', 'count': '40029'},
#        {'item': '3', 'count': '6838'},
#        {'item': '6', 'count': '4102'},
#        {'item': '4', 'count': '2940'},
#        {'item': '5', 'count': '1456'},
#        {'item': '7', 'count': '547'},
#        {'item': '8', 'count': '333'},
#        {'item': '9', 'count': '206'},
#        {'item': '10', 'count': '174'},
#        {'item': '11', 'count': '121'},
#        {'item': '12', 'count': '110'},
#        {'item': '13', 'count': '78'},
#        {'item': '14', 'count': '51'},
#        {'item': '15', 'count': '47'},
#        {'item': '16', 'count': '31'},
#        {'item': '18', 'count': '29'},
#        {'item': '17', 'count': '28'},
#        {'item': '19', 'count': '22'},
#        {'item': '20', 'count': '22'}],
#       'smallest': '1',
#       'null': '119',
#       'non_null': '6618824',
#       'largest': '117',
#       'count': '6618943',
#       'cardinality': '42'}},
#     {'tableColumnId': 139408258,
#      'renderTypeName': 'calendar_date',
#      'position': 27,
#      'name': 'UnderReview',
#      'id': 552437373,
#      'format': {},
#      'fieldName': 'underreview',
#      'description': '',
#      'dataTypeName': 'calendar_date',
#      'cachedContents': {'top': [{'item': '2021-03-03T11:13:49.050',
#         'count': '213'},
#        {'item': '2021-03-04T14:44:21.003', 'count': '172'},
#        {'item': '2021-04-05T13:16:15.817', 'count': '129'},
#        {'item': '2021-04-05T10:27:54.777', 'count': '120'},
#        {'item': '2021-04-05T11:00:30.717', 'count': '110'},
#        {'item': '2021-04-05T13:28:32.697', 'count': '108'},
#        {'item': '2021-07-12T07:58:47.307', 'count': '108'},
#        {'item': '2020-12-07T12:05:24.180', 'count': '103'},
#        {'item': '2021-11-10T13:30:41.820', 'count': '103'},
#        {'item': '2021-04-23T11:28:35.493', 'count': '101'},
#        {'item': '2021-07-28T19:57:45.483', 'count': '99'},
#        {'item': '2021-07-09T08:59:22.927', 'count': '98'},
#        {'item': '2021-07-09T07:01:15.183', 'count': '97'},
#        {'item': '2021-06-10T15:52:34.803', 'count': '96'},
#        {'item': '2021-04-26T08:07:28.153', 'count': '94'},
#        {'item': '2021-06-22T15:14:20.580', 'count': '93'},
#        {'item': '2021-03-19T13:29:53.750', 'count': '91'},
#        {'item': '2021-04-05T11:29:49.880', 'count': '91'},
#        {'item': '2021-03-19T14:06:57.450', 'count': '90'},
#        {'item': '2021-11-30T10:49:10.587', 'count': '89'}],
#       'smallest': '2017-10-17T15:57:44.000',
#       'null': '14938',
#       'non_null': '6604005',
#       'largest': '2021-12-12T00:00:11.333',
#       'count': '6618943',
#       'cardinality': '3942067'}},
#     {'tableColumnId': 139408265,
#      'renderTypeName': 'calendar_date',
#      'position': 28,
#      'name': 'Reviewed',
#      'id': 552437374,
#      'format': {},
#      'fieldName': 'reviewed',
#      'description': '',
#      'dataTypeName': 'calendar_date',
#      'cachedContents': {'top': [{'item': '2021-03-04T15:21:35.020',
#         'count': '172'},
#        {'item': '2021-04-05T14:17:14.490', 'count': '129'},
#        {'item': '2021-04-05T10:58:15.360', 'count': '120'},
#        {'item': '2021-04-05T14:04:24.140', 'count': '108'},
#        {'item': '2021-07-12T08:09:40.580', 'count': '108'},
#        {'item': '2020-12-07T12:12:12.713', 'count': '103'},
#        {'item': '2021-11-10T14:15:19.903', 'count': '103'},
#        {'item': '2021-04-23T11:49:45.220', 'count': '101'},
#        {'item': '2021-07-28T20:13:27.747', 'count': '99'},
#        {'item': '2021-07-09T12:57:52.610', 'count': '98'},
#        {'item': '2021-07-09T07:35:24.843', 'count': '97'},
#        {'item': '2021-06-10T16:07:28.207', 'count': '96'},
#        {'item': '2021-04-26T08:46:59.133', 'count': '94'},
#        {'item': '2021-04-05T12:36:25.610', 'count': '93'},
#        {'item': '2021-06-22T15:30:54.633', 'count': '93'},
#        {'item': '2021-04-05T11:48:24.553', 'count': '91'},
#        {'item': '2021-03-19T15:09:31.717', 'count': '90'},
#        {'item': '2021-06-10T14:13:24.167', 'count': '89'},
#        {'item': '2021-11-03T12:48:04.073', 'count': '89'},
#        {'item': '2021-03-19T13:50:41.473', 'count': '89'}],
#       'smallest': '2017-10-17T16:01:24.290',
#       'null': '455507',
#       'non_null': '6163436',
#       'largest': '2021-12-12T00:01:33.227',
#       'count': '6618943',
#       'cardinality': '3720214'}},
#     {'tableColumnId': 139408240,
#      'renderTypeName': 'number',
#      'position': 29,
#      'name': 'PrimaryAmount',
#      'id': 552437375,
#      'format': {},
#      'fieldName': 'primaryamount',
#      'description': '',
#      'dataTypeName': 'number',
#      'cachedContents': {'top': [{'item': '0.0000', 'count': '4777163'},
#        {'item': '189.0000', 'count': '193303'},
#        {'item': '379.0000', 'count': '147944'},
#        {'item': '388.0000', 'count': '107260'},
#        {'item': '6.0000', 'count': '103805'},
#        {'item': '287.0000', 'count': '87272'},
#        {'item': '30.0000', 'count': '54378'},
#        {'item': '251.0000', 'count': '49118'},
#        {'item': '5.0000', 'count': '47595'},
#        {'item': '314.0000', 'count': '44609'},
#        {'item': '89.0000', 'count': '39930'},
#        {'item': '463.5000', 'count': '37056'},
#        {'item': '50.0000', 'count': '36508'},
#        {'item': '45.0000', 'count': '28489'},
#        {'item': '293.0000', 'count': '26272'},
#        {'item': '364.0000', 'count': '24427'},
#        {'item': '284.0000', 'count': '23524'},
#        {'item': '75.0000', 'count': '23341'},
#        {'item': '334.0000', 'count': '23297'},
#        {'item': '256.0000', 'count': '22533'}],
#       'smallest': '0.0000',
#       'null': '0',
#       'non_null': '6618943',
#       'largest': '9408.0000',
#       'count': '6618943',
#       'cardinality': '2354'}},
#     {'tableColumnId': 139408238,
#      'renderTypeName': 'number',
#      'position': 30,
#      'name': 'SecondaryAmount',
#      'id': 552437376,
#      'format': {},
#      'fieldName': 'secondaryamount',
#      'description': '',
#      'dataTypeName': 'number',
#      'cachedContents': {'top': [{'item': '0.0000', 'count': '4688904'},
#        {'item': '0.2500', 'count': '530825'},
#        {'item': '10.9500', 'count': '119861'},
#        {'item': '0.1700', 'count': '82851'},
#        {'item': '1.0300', 'count': '71992'},
#        {'item': '11.2100', 'count': '69159'},
#        {'item': '8.2900', 'count': '63980'},
#        {'item': '3.0800', 'count': '58414'},
#        {'item': '3.0900', 'count': '40601'},
#        {'item': '7.2500', 'count': '35302'},
#        {'item': '0.8700', 'count': '34582'},
#        {'item': '0.1400', 'count': '32956'},
#        {'item': '1.2500', 'count': '26854'},
#        {'item': '3.2500', 'count': '26091'},
#        {'item': '9.0700', 'count': '25642'},
#        {'item': '13.4000', 'count': '25178'},
#        {'item': '2.5700', 'count': '24479'},
#        {'item': '1.4400', 'count': '24282'},
#        {'item': '1.3000', 'count': '20133'},
#        {'item': '8.2100', 'count': '18417'}],
#       'smallest': '-1.0000',
#       'null': '0',
#       'non_null': '6618943',
#       'largest': '271.8900',
#       'count': '6618943',
#       'cardinality': '1805'}},
#     {'tableColumnId': 139408249,
#      'renderTypeName': 'text',
#      'position': 31,
#      'name': 'SystemPaymentAccountType',
#      'id': 552437377,
#      'format': {},
#      'fieldName': 'systempaymentaccounttype',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'top': [{'item': 'CreditCard', 'count': '3824787'},
#        {'item': 'BankAccount', 'count': '1658336'},
#        {'item': 'Waiver', 'count': '1057883'},
#        {'item': 'Cash', 'count': '7380'}],
#       'smallest': 'BankAccount',
#       'null': '70557',
#       'non_null': '6548386',
#       'largest': 'Waiver',
#       'count': '6618943',
#       'cardinality': '4'}},
#     {'tableColumnId': 139408242,
#      'renderTypeName': 'text',
#      'position': 32,
#      'name': 'Clerkname',
#      'id': 552437378,
#      'format': {},
#      'fieldName': 'clerkname',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'top': [{'item': 'Edwards, Michele',
#         'count': '120683'},
#        {'item': 'Rose, Abbey', 'count': '112230'},
#        {'item': 'Shipbaugh, Coleen', 'count': '102519'},
#        {'item': 'LOFTON, SHANELL', 'count': '100584'},
#        {'item': 'Carney, Theresa', 'count': '98570'},
#        {'item': 'THOMAS, Michelle', 'count': '73761'},
#        {'item': 'Forbes, Sara', 'count': '72492'},
#        {'item': 'Sumrall, Vonda', 'count': '70920'},
#        {'item': 'Wilson, Diane', 'count': '62797'},
#        {'item': 'Battiato, Shannon', 'count': '62299'},
#        {'item': 'Griffin, Natasha D.', 'count': '58529'},
#        {'item': 'Lovell, John', 'count': '58141'},
#        {'item': 'Reyes, Debra', 'count': '53679'},
#        {'item': 'Delrose, Alexa', 'count': '52049'},
#        {'item': 'Joshi, Sonal', 'count': '49559'},
#        {'item': 'Mojica, Cecilia', 'count': '49102'},
#        {'item': 'Kennerly, Sara', 'count': '48059'},
#        {'item': 'System, System', 'count': '47667'},
#        {'item': 'Ledesma, D', 'count': '47401'},
#        {'item': 'Demos, Elena', 'count': '47284'}],
#       'smallest': '2 Admin, Cook District',
#       'null': '455507',
#       'non_null': '6163436',
#       'largest': 'Zurawska, Anna',
#       'count': '6618943',
#       'cardinality': '1510'}},
#     {'tableColumnId': 139408261,
#      'renderTypeName': 'calendar_date',
#      'position': 33,
#      'name': 'AdjustedSubmitDate',
#      'id': 552437379,
#      'format': {},
#      'fieldName': 'adjustedsubmitdate',
#      'description': '',
#      'dataTypeName': 'calendar_date',
#      'cachedContents': {'top': [{'item': '2021-11-15T07:00:00.000',
#         'count': '4529'},
#        {'item': '2021-02-22T07:00:00.000', 'count': '4352'},
#        {'item': '2021-02-01T07:00:00.000', 'count': '4338'},
#        {'item': '2020-12-21T07:00:00.000', 'count': '4039'},
#        {'item': '2021-01-11T07:00:00.000', 'count': '3995'},
#        {'item': '2020-12-07T07:00:00.000', 'count': '3935'},
#        {'item': '2021-03-01T07:00:00.000', 'count': '3932'},
#        {'item': '2021-02-08T07:00:00.000', 'count': '3847'},
#        {'item': '2021-11-22T07:00:00.000', 'count': '3768'},
#        {'item': '2021-01-18T07:00:00.000', 'count': '3695'},
#        {'item': '2021-12-13T07:00:00.000', 'count': '3573'},
#        {'item': '2021-06-28T07:00:00.000', 'count': '3513'},
#        {'item': '2021-10-25T07:00:00.000', 'count': '3363'},
#        {'item': '2021-03-08T07:00:00.000', 'count': '3275'},
#        {'item': '2021-01-25T07:00:00.000', 'count': '3249'},
#        {'item': '2020-12-14T07:00:00.000', 'count': '3235'},
#        {'item': '2021-02-15T07:00:00.000', 'count': '3234'},
#        {'item': '2021-11-01T07:00:00.000', 'count': '3190'},
#        {'item': '2021-08-02T07:00:00.000', 'count': '3021'},
#        {'item': '2021-03-15T07:00:00.000', 'count': '2937'}],
#       'smallest': '2017-02-09T19:08:04.260',
#       'null': '2656',
#       'non_null': '6616287',
#       'largest': '2021-12-13T07:00:00.000',
#       'count': '6618943',
#       'cardinality': '3850456'}},
#     {'tableColumnId': 139408267,
#      'renderTypeName': 'number',
#      'position': 34,
#      'name': 'ClerkResponseTime',
#      'id': 552437380,
#      'format': {},
#      'fieldName': 'clerkresponsetime',
#      'description': '',
#      'dataTypeName': 'number',
#      'cachedContents': {'top': [{'item': '1', 'count': '186642'},
#        {'item': '2', 'count': '184425'},
#        {'item': '3', 'count': '150729'},
#        {'item': '4', 'count': '126634'},
#        {'item': '5', 'count': '108588'},
#        {'item': '6', 'count': '94377'},
#        {'item': '0', 'count': '90793'},
#        {'item': '7', 'count': '84597'},
#        {'item': '8', 'count': '76139'},
#        {'item': '9', 'count': '69721'},
#        {'item': '10', 'count': '63562'},
#        {'item': '11', 'count': '59088'},
#        {'item': '12', 'count': '55891'},
#        {'item': '13', 'count': '52549'},
#        {'item': '14', 'count': '49154'},
#        {'item': '15', 'count': '47891'},
#        {'item': '16', 'count': '45579'},
#        {'item': '17', 'count': '43131'},
#        {'item': '18', 'count': '41043'},
#        {'item': '19', 'count': '39109'}],
#       'smallest': '-3719',
#       'null': '457668',
#       'non_null': '6161275',
#       'largest': '2528106',
#       'count': '6618943',
#       'cardinality': '22932'}},
#     {'tableColumnId': 139408235,
#      'renderTypeName': 'text',
#      'position': 35,
#      'name': 'InsertedBy',
#      'id': 552437381,
#      'format': {},
#      'fieldName': 'insertedby',
#      'description': '',
#      'dataTypeName': 'text',
#      'cachedContents': {'null': '6618943',
#       'non_null': '0',
#       'count': '6618943',
#       'cardinality': '0'}}],
#    'clientContext': {'clientContextVariables': []},
#    'category': None,
#    'attributionLink': None,
#    'attribution': None},
#   'id': 63844423,
#   'href': [],
#   'fourfour': '7pzs-jtti',
#   'domain_id': 3749,
#   'creation_source': None,
#   'created_by': {'user_id': 'mr6k-jk9m',
#    'email': 'david.torres@tylertech.com',
#    'display_name': 'David Torres'},
#   'created_at': '2022-12-19T06:01:22.194703Z',
#   'closed_at': '2022-12-19T06:02:13',
#   'blob_id': None,
#   'attachments': [],
#   'archive': None,
#   'action': {'type': 'update', 'permission': None}},
#  'links': {'update': '/api/publishing/v1/revision/7pzs-jtti/514',
#   'show': '/api/publishing/v1/revision/7pzs-jtti/514',
#   'plan': '/api/publishing/v1/revision/7pzs-jtti/514/plan',
#   'list_sources': '/api/publishing/v1/revision/7pzs-jtti/514/source',
#   'export_errors': '/api/publishing/v1/source/62881746/schema/61629805/errors/63891532',
#   'discard': '/api/publishing/v1/revision/7pzs-jtti/514',
#   'create_source': '/api/publishing/v1/revision/7pzs-jtti/514/source',
#   'apply': '/api/publishing/v1/revision/7pzs-jtti/514/apply'}}

# %%
rev_1_resource.keys()
# Out:
# dict_keys(['updated_at', 'task_sets', 'revision_seq', 'permissions', 'output_schema_id', 'notes', 'metadata', 'id', 'href', 'fourfour', 'domain_id', 'creation_source', 'created_by', 'created_at', 'closed_at', 'blob_id', 'attachments', 'archive', 'action'])

# %%
rev_1_resource['task_sets'][0].keys()
# Out:
# dict_keys(['updated_at', 'status', 'request_id', 'output_schema_id', 'log', 'job_uuid', 'is_edit', 'id', 'finished_at', 'created_by', 'created_at'])

# %%
rev_1_resource['permissions']
# Out:
# {}

# %%
rev_1_resource['notes'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 rev_1_resource['notes'].keys()
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
rev_1_resource['metadata'].keys()
# Out:
# dict_keys(['tags', 'queryString', 'privateMetadata', 'name', 'metadata', 'measure', 'licenseId', 'license', 'inputs', 'displayType', 'displayFormat', 'description', 'columns', 'clientContext', 'category', 'attributionLink', 'attribution'])

# %% [markdown]
# Column metadata:

# %%
rev_1_resource['metadata']['columns'][0]
# Out:
# {'tableColumnId': 139408245,
#  'renderTypeName': 'number',
#  'position': 1,
#  'name': 'RowKey',
#  'id': 552437347,
#  'format': {},
#  'fieldName': 'rowkey',
#  'description': '',
#  'dataTypeName': 'number',
#  'cachedContents': {'top': [{'item': '207433', 'count': '1'},
#    {'item': '410489', 'count': '1'},
#    {'item': '683251', 'count': '1'},
#    {'item': '2553566', 'count': '1'},
#    {'item': '2625181', 'count': '1'},
#    {'item': '2693764', 'count': '1'},
#    {'item': '2757192', 'count': '1'},
#    {'item': '3358189', 'count': '1'},
#    {'item': '4529425', 'count': '1'},
#    {'item': '4529437', 'count': '1'},
#    {'item': '4529454', 'count': '1'},
#    {'item': '4813603', 'count': '1'},
#    {'item': '4813650', 'count': '1'},
#    {'item': '4813690', 'count': '1'},
#    {'item': '4813782', 'count': '1'},
#    {'item': '5626865', 'count': '1'},
#    {'item': '5626888', 'count': '1'},
#    {'item': '7066596', 'count': '1'},
#    {'item': '7066654', 'count': '1'},
#    {'item': '7066712', 'count': '1'}],
#   'smallest': '4474',
#   'null': '0',
#   'non_null': '6618943',
#   'largest': '25718299',
#   'count': '6618943',
#   'cardinality': '6618943'}}

# %%
print("Revision 1 Metadata")
print("Column: " + rev_1_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_1_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_1_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_1_resource['metadata']['columns'][0]['cachedContents']['non_null'])
print("                        ")
print("Revision 2 Metadata")
print("Column: " + rev_2_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_2_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_2_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_2_resource['metadata']['columns'][0]['cachedContents']['non_null'])
print("                        ")
print("Revision 3 Metadata")
print("Column: " + rev_3_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_3_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_3_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_3_resource['metadata']['columns'][0]['cachedContents']['non_null'])
print("                        ")
print("Revision 4 Metadata")
print("Column: " + rev_4_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_4_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_4_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_4_resource['metadata']['columns'][0]['cachedContents']['non_null'])
print("                        ")
print("Revision 5 Metadata")
print("Column: " + rev_5_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['non_null'])
print("Revision 5 Metadata")
print("Column: " + rev_5_resource['metadata']['columns'][0]['name'])
print("Count: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['count'])
print("Null: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['null'])
print("Non-null: " + rev_5_resource['metadata']['columns'][0]['cachedContents']['non_null'])
# Out:
# Revision 1 Metadata
# Column: RowKey
# Count: 6618943
# Null: 0
# Non-null: 6618943
#
# Revision 2 Metadata
# Column: RowKey
# Count: 6618943
# Null: 0
# Non-null: 6618943
#
# Revision 3 Metadata
# Column: RowKey
# Count: 6618943
# Null: 0
# Non-null: 6618943
#
# Revision 4 Metadata
# Column: RowKey
# Count: 6618943
# Null: 0
# Non-null: 6618943
#
# Revision 5 Metadata
# Column: RowKey
# Count: 6618943
# Null: 0
# Non-null: 6618943

# %% [markdown]
# What about the `metadata` endpoint?

# %%
response = requests.get(f'{domain}/api/views/metadata/v1/{dataset_id}', 
                        auth=(username,password), 
                        stream=True)
metadata = response.json()

# %%
metadata
# Out:
# {'id': '7pzs-jtti',
#  'name': 'e-File AOIC Prod Filings',
#  'attribution': None,
#  'attributionLink': None,
#  'category': None,
#  'createdAt': '2021-08-26T15:55:08+0000',
#  'dataUpdatedAt': '2023-01-06T06:02:13+0000',
#  'dataUri': 'https://internal-aoic.data.socrata.com/resource/7pzs-jtti',
#  'description': None,
#  'domain': 'internal-aoic.data.socrata.com',
#  'externalId': None,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'license': None,
#  'metadataUpdatedAt': '2023-01-06T06:01:54+0000',
#  'provenance': 'OFFICIAL',
#  'updatedAt': '2023-01-06T06:01:54+0000',
#  'webUri': 'https://internal-aoic.data.socrata.com/d/7pzs-jtti',
#  'approvals': [{'state': 'submittable',
#    'submissionObject': 'public_audience_request',
#    'submissionOutcome': 'change_audience',
#    'workflowId': 3104,
#    'submissionDetails': {'permissionType': 'READ'}}],
#  'customFields': None,
#  'tags': None}
